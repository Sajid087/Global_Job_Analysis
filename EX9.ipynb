# %% [markdown]
# Exercise 2

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
df = pd.read_csv('data_jobs.csv')
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA = df[df['job_title_short']=='Data Analyst'].copy()
df_DA
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# 12                      Lyon, France
# 18                    Warsaw, Poland
# 31                     Paris, France
# 34                 Erlangen, Germany
# ...                              ...
# 785703                      Anywhere
# 785705                   Oakland, CA
# 785715                         India
# 785717                Erfurt, Jerman
# 785737            Bad Rodach, Jerman
#
#                                                   job_via  \
# 1                                        via BeBee México
# 12                                           via Jobijoba
# 18                                  via Praca Trabajo.org
# 31                                           via LinkedIn
# 34                        via Central Illinois Proud Jobs
# ...                                                   ...
# 785703                                       via Snagajob
# 785705                                       via Snagajob
# 785715  melalui Jobsleworld - Jobs In India - Job Vaca...
# 785717                                   melalui LinkedIn
# 785737                          melalui BeBee Deutschland
#
#                job_schedule_type  job_work_from_home  \
# 1                      Full-time               False
# 12      Full-time and Internship               False
# 18                     Full-time               False
# 31      Full-time and Internship               False
# 34                     Full-time               False
# ...                          ...                 ...
# 785703                 Full-time                True
# 785705                 Full-time               False
# 785715           Pekerjaan tetap               False
# 785717           Pekerjaan tetap               False
# 785737           Pekerjaan tetap               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 1                          Mexico 2023-01-14 13:18:07                  False
# 12                         France 2023-12-22 13:24:41                  False
# 18                         Poland 2023-10-16 13:36:54                  False
# 31                         France 2023-10-19 13:59:31                  False
# 34                        Germany 2023-02-23 13:31:28                   True
# ...                           ...                 ...                    ...
# 785703       Texas, United States 2023-01-28 06:02:55                   True
# 785705  California, United States 2023-01-09 06:00:25                  False
# 785715                      India 2023-03-13 06:16:28                  False
# 785717                    Germany 2023-03-12 06:18:18                  False
# 785737                    Germany 2023-03-12 06:18:18                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 1                      False         Mexico         NaN              NaN
# 12                     False         France         NaN              NaN
# 18                     False         Poland         NaN              NaN
# 31                     False         France         NaN              NaN
# 34                     False        Germany         NaN              NaN
# ...                      ...            ...         ...              ...
# 785703                 False  United States         NaN              NaN
# 785705                 False  United States         NaN              NaN
# 785715                 False          India         NaN              NaN
# 785717                 False        Germany         NaN              NaN
# 785737                 False        Germany         NaN              NaN
#
#         salary_hour_avg                                       company_name  \
# 1                   NaN                         Hewlett Packard Enterprise
# 12                  NaN                                              Engie
# 18                  NaN                                              Glovo
# 31                  NaN  GROUPE BON MARCHÉ : Le Bon Marché Rive Gauche ...
# 34                  NaN                                       DEFACTO GmbH
# ...                 ...                                                ...
# 785703              NaN                        Axelon Services Corporation
# 785705              NaN                                   PG&E Corporation
# 785715              NaN                                               Amul
# 785717              NaN                                      NTT DATA DACH
# 785737              NaN                                   HABA FAMILYGROUP
#
#                                                job_skills  \
# 1              [r, python, sql, nosql, power bi, tableau]
# 12                 [sql, php, excel, power bi, sap, jira]
# 18      [sql, python, r, redshift, pandas, excel, look...
# 31                                                  [sql]
# 34                                                  [sap]
# ...                                                   ...
# 785703                                                NaN
# 785705                             [sql, python, tableau]
# 785715                                                NaN
# 785717                                       [aws, azure]
# 785737                             [sas, sas, sql, excel]
#
#                                           job_type_skills
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 12      {'analyst_tools': ['excel', 'power bi', 'sap']...
# 18      {'analyst_tools': ['excel', 'looker', 'tableau...
# 31                               {'programming': ['sql']}
# 34                             {'analyst_tools': ['sap']}
# ...                                                   ...
# 785703                                                NaN
# 785705  {'analyst_tools': ['tableau'], 'programming': ...
# 785715                                                NaN
# 785717                        {'cloud': ['aws', 'azure']}
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
#
# [196075 rows x 17 columns]

# %%
df_DA_explode = df_DA.explode('job_skills')
df_DA_explode['job_posted_month'] = df_DA_explode['job_posted_date'].dt.month
df_DA_explode.sample(10)
# Out:
#        job_title_short                                          job_title  \
# 441834    Data Analyst                           CRM Data Analyst (m/w/d)
# 740499    Data Analyst  Data Analyst II - SQL Reporting. Job in Pompan...
# 590737    Data Analyst                                   Nbi Data Analyst
# 686737    Data Analyst                                       Data Analist
# 86565     Data Analyst                           Specialista Data Analyst
# 489928    Data Analyst                               Data Analyst (m/w/d)
# 721391    Data Analyst                      Lead Advancement Data Analyst
# 68551     Data Analyst  Supply Chain Data Analyst Apprenticeship - Lev...
# 416007    Data Analyst                                       Data Analyst
# 305931    Data Analyst                                       Data Analyst
#
#                     job_location                   job_via  \
# 441834            Oyten, Germany                  via XING
# 740499         Pompano Beach, FL  via My Valley Jobs Today
# 590737             Madrid, Spain                 via BeBee
# 686737  Barendrecht, Netherlands                via Adzuna
# 86565                      Italy              via Sercanto
# 489928         Dortmund, Germany                  via XING
# 721391                Orange, CA                via Indeed
# 68551               Stafford, UK   via Caterpillar Careers
# 416007            Kilmarnock, UK                 via BeBee
# 305931            Washington, DC           via Trabajo.org
#
#               job_schedule_type  job_work_from_home  \
# 441834                Full-time               False
# 740499                Full-time               False
# 590737                Full-time               False
# 686737                Full-time               False
# 86565                 Full-time               False
# 489928                Full-time               False
# 721391                Full-time               False
# 68551                 Full-time               False
# 416007  Part-time and Temp work               False
# 305931                Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 441834                    Germany 2023-01-26 16:24:07                   True
# 740499     Florida, United States 2023-01-17 21:03:36                  False
# 590737                      Spain 2023-11-08 09:45:44                  False
# 686737                Netherlands 2023-08-13 10:15:09                   True
# 86565                       Italy 2023-04-07 00:20:58                  False
# 489928                    Germany 2023-07-17 11:53:53                   True
# 721391  California, United States 2023-03-29 21:01:57                  False
# 68551              United Kingdom 2023-05-03 06:40:56                  False
# 416007             United Kingdom 2023-11-15 16:15:44                  False
# 305931    New York, United States 2023-05-24 17:00:08                   True
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 441834                 False         Germany         NaN              NaN
# 740499                  True   United States         NaN              NaN
# 590737                 False           Spain         NaN              NaN
# 686737                 False     Netherlands         NaN              NaN
# 86565                  False           Italy         NaN              NaN
# 489928                 False         Germany         NaN              NaN
# 721391                 False   United States         NaN              NaN
# 68551                  False  United Kingdom         NaN              NaN
# 416007                 False  United Kingdom         NaN              NaN
# 305931                 False   United States         NaN              NaN
#
#         salary_hour_avg                  company_name  job_skills  \
# 441834              NaN                      MW PARTS         NaN
# 740499              NaN    Sunshine State Health Plan       excel
# 590737              NaN                     Santander     pyspark
# 686737              NaN                   Careervalue      python
# 86565               NaN              Talent - organic       excel
# 489928              NaN              Computer Futures           r
# 721391              NaN            Chapman University           r
# 68551               NaN                   Caterpillar     outlook
# 416007              NaN                      Abs Data         NaN
# 305931              NaN  PATRIOT SOLUTIONS GROUP, LLC  javascript
#
#                                           job_type_skills  job_posted_month
# 441834                                                NaN                 1
# 740499  {'analyst_tools': ['excel'], 'programming': ['...                 1
# 590737  {'libraries': ['pyspark', 'gdpr'], 'programmin...                11
# 686737  {'analyst_tools': ['power bi'], 'programming':...                 8
# 86565                        {'analyst_tools': ['excel']}                 4
# 489928  {'analyst_tools': ['power bi'], 'programming':...                 7
# 721391  {'analyst_tools': ['power bi', 'tableau', 'alt...                 3
# 68551   {'analyst_tools': ['word', 'excel', 'outlook']...                 5
# 416007                                                NaN                11
# 305931             {'programming': ['sql', 'javascript']}                 5

# %%
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month', columns='job_skills', aggfunc='size', fill_value=0)

# %%
df_DA_pivot.loc['Total']= df_DA_pivot.sum()

df_DA_pivot=df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
df_DA_pivot = df_DA_pivot.drop('Total')
df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# 1                 11336   8170    6606     5596      4285  3607  3830
# 2                  7947   5772    4751     3936      3307  2576  2634
# 3                  7868   5675    4741     4051      3176  2650  2554
# 4                  7553   5496    4557     3776      3106  2399  2598
# 5                  6617   4773    4070     3245      2695  2093  1940
# 6                  7584   5724    4707     3812      3275  2442  2174
# 7                  7687   5513    4831     3928      3350  2444  2118
# 8                  8823   6482    5576     4533      3859  2975  2560
# 9                  6829   4886    4229     3446      3118  2146  1880
# 10                 7474   5217    4693     3709      3340  2380  2114
# 11                 6652   4776    4233     3284      3012  2159  1738
# 12                 6058   4376    4196     3139      2857  2125  1858
#
# job_skills        powerpoint  word   sap  ...  angular.js  xamarin  gtx  \
# job_posted_month                          ...
# 1                       1880  1778  1251  ...           2        0    0
# 2                       1291  1235   954  ...           0        0    0
# 3                       1266  1203   892  ...           0        1    0
# 4                       1190  1177   947  ...           0        0    0
# 5                        979   957   851  ...           0        0    0
# 6                       1173  1237   987  ...           0        0    0
# 7                       1096  1069   996  ...           0        0    1
# 8                       1332  1298  1117  ...           0        0    0
# 9                        944   945   852  ...           0        0    0
# 10                       955   990   872  ...           0        1    0
# 11                       894   887   808  ...           0        0    0
# 12                       822   786   753  ...           0        0    0
#
# job_skills        nuxt.js  ovh  esquisse  suse  capacitor  chainer  msaccess
# job_posted_month
# 1                       1    0         0     0          1        0         0
# 2                       0    0         0     0          0        0         0
# 3                       0    0         0     1          0        0         0
# 4                       0    1         0     0          0        0         0
# 5                       0    0         0     0          0        0         1
# 6                       0    0         0     0          0        0         0
# 7                       0    0         0     0          0        0         0
# 8                       0    0         0     0          0        0         0
# 9                       0    0         0     0          0        0         0
# 10                      0    0         0     0          0        0         0
# 11                      0    0         1     0          0        0         0
# 12                      0    0         0     0          0        1         0
#
# [12 rows x 235 columns]

# %%
df_DA_pivot.iloc[:,:5].plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>
